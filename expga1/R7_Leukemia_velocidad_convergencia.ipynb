# %%
augmented = [
    10, 8, 11, 8, 10, 19, 11, 9, 12, # 0006
    12,13,11,9,13,15,10,     # 0009 
    ]
original = [
    13, 11, 6, 14, 12, 16, 11, 9, 11, # 0012
    13,6,12, 9,12,10
    ]

# %%
import numpy as np

print(np.median(augmented))
print(np.median(original))
# Out:
# 11.0
# 11.0

# %%
# crete a boxplot for augmented and original
import matplotlib.pyplot as plt
plt.boxplot([augmented, original], labels=['augmented', 'original'])
plt.show()
